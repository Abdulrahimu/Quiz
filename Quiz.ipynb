# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Abdulrahim/Documents/HamoyeQuiz/FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding = "latin-1")
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %%
len(df)
# Out:
# 60943

# %% [markdown]
# ### Perform a groupby operation on "Element". What is the total number of the sum of processing in 2017?

# %%
df.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# ### If you have the following list...

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ['Age','Nationality','Overall']

# %%
pd.DataFrame(lst,columns=col,index=[i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %% [markdown]
# ### What is the total number of unique countries in the dataset?

# %%
df['Area'].nunique()
# Out:
# 49

# %% [markdown]
# ### Select columns "Y2017" and "Area"

# %%
df[["Y2017","Area"]].groupby("Area").sum().sort_values(by="Y2017",ascending=False)
# Out:
#                                   Y2017
# Area
# Nigeria                      1483268.23
# Egypt                         866379.92
# South Africa                  517590.54
# Ethiopia                      448683.76
# Morocco                       388495.36
# Ghana                         337599.06
# Algeria                       325644.27
# United Republic of Tanzania   322616.85
# Kenya                         264660.66
# Sudan                         239931.92
# Cameroon                      232030.43
# Angola                        229159.57
# Côte d'Ivoire                 224599.01
# Uganda                        213950.38
# Malawi                        181098.71
# Mozambique                    161407.98
# Mauritania                    156665.46
# Mali                          149928.33
# Madagascar                    131197.73
# Niger                         126707.58
# Benin                         124771.22
# Tunisia                       124167.20
# ...

# %% [markdown]
# ### Given the following python code, what would the output of the code give?

# %%
my_tuppy = (1,2,5,8)
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ABDULR~1\AppData\Local\Temp/ipykernel_12972/3506354595.py in <module>
#       1 my_tuppy = (1,2,5,8)
# ----> 2 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### What is the total nymber and percentage of missing data in 2014

# %%
df["Y2014"].isna().sum()
# Out:
# 1589

# %%
df["Y2014"].isna().sum()/60943
# Out:
# 0.026073544131401474

# %%
df[["Area","Element"]].value_counts()
# Out:
# Area                         Element
# Congo                        Domestic supply quantity         119
# United Republic of Tanzania  Domestic supply quantity         119
# Chad                         Domestic supply quantity         119
# Mozambique                   Domestic supply quantity         119
# Rwanda                       Domestic supply quantity         119
#                                                              ...
#                              Total Population - Both sexes      1
# Ethiopia PDR                 Feed                               1
# United Republic of Tanzania  Total Population - Both sexes      1
# Lesotho                      Total Population - Both sexes      1
# Zimbabwe                     Total Population - Both sexes      1
# Length: 803, dtype: int64

# %% [markdown]
# ### What is the protein supply quantity in Madagascar?

# %%
df.groupby(["Area","Element"]).sum()
# Out:
#                                                  Area Code  Item Code  \
# Area     Element
# Algeria  Domestic supply quantity                      464     311204
#          Export Quantity                               392     264011
#          Fat supply quantity (g/capita/day)            432     291489
#          Feed                                           88      58967
#          Food                                          420     282744
# ...                                                    ...        ...
# Zimbabwe Protein supply quantity (g/capita/day)      20453     304589
#          Residuals                                   18824     277476
#          Seed                                         3439      50560
#          Stock Variation                             17195     254157
#          Total Population - Both sexes                 181       2501
#
#                                                  Element Code     Y2014  \
# Area     Element
# ...

# %%
a = df.groupby(["Area","Element"]).sum()

# %%
a.loc["Madagascar"]
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                    15351     318888        630819
# Export Quantity                             13416     279445        614744
# Fat supply quantity (g/capita/day)          14319     299405         75924
# Feed                                         4515      94030        193235
# Food                                        14190     295817        565620
# Food supply (kcal/capita/day)               14319     299405         73704
# Food supply quantity (kg/capita/yr)         14190     295817         70950
# Import Quantity                             14319     297945        622821
# Losses                                       7095     148102        281765
# Other uses (non-food)                        6579     138246        262854
# Processing                                   9804     201929        389956
# ...

# %% [markdown]
# ### Select columns "Y2017" and "Area". Perform a groupby operation on 'Area'...

# %%
df[["Y2017","Area"]].groupby("Area").sum().sort_values(by = "Y2017").head(7)
# Out:
#                           Y2017
# Area
# Sudan (former)             0.00
# Ethiopia PDR               0.00
# Comoros                   59.84
# Seychelles               442.34
# Sao Tome and Principe  12662.63
# Cabo Verde             14650.74
# Guinea-Bissau          19102.77

# %% [markdown]
# ### What is the mean and standard deviation across the whole dataset for the year 2017

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.describe(include="all")
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %% [markdown]
# ### Which year had the least correlation with "Element code"

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %% [markdown]
# ### What is the total sum of Wine produced in 2015 and 2018 respectively

# %%
a=df.groupby("Item").sum()

# %%
a.loc["Wine"]
# Out:
# Area Code         66206.00
# Item Code       1319535.00
# Element Code    1818328.00
# Y2014              4497.36
# Y2015              4251.81
# Y2016              3872.09
# Y2017              4178.02
# Y2018              4039.32
# Name: Wine, dtype: float64

# %% [markdown]
# ### Perform a groupby operation on "Element". What year has the highest sum of Stock Variation?

# %%
b = df.groupby("Element").sum()

# %%
b
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
b.loc["Stock Variation"]
# Out:
# Area Code         571566.00
# Item Code       11329527.00
# Element Code    21464704.00
# Y2014              58749.83
# Y2015              34910.99
# Y2016              33140.12
# Y2017              54316.91
# Y2018              20577.91
# Name: Stock Variation, dtype: float64

# %%
S = [['him', 'sell'], [90, 28, 43]]

# %%
S[0][1][1]
# Out:
# 'e'
